# %% [markdown]
# # Rhys Cooper,
#
# Data Science and AI, C3718986
#
# **I am submitting Exam Paper 3**

# %% [markdown]
# # How I work the best
#
# ### Ways in which I work the best:
#
# * In a place with minimal distractions
# * Places where I can seek help if I get stuck
# * Independant areas
# * Also places where I can interact with people
#
# ### Description:
#
# I generally work best in programming when I am given a task and can be left **independantly** but also at the same time if I hit any issues or errors I am able to seak help from **tutors** or **peers** and they are able to give me input in how I am able to fix the problem I have run into.
#
# *I also believe I work best when I am able to have breaks whenever I feel like it as I believe by working too hard sometimes you are not able to see clear errors and by having small breaks in between you are more likely to solve these errors as you aren't looking into too much detail which sometimes makes you miss the most basic things.*

# %%
time = float(input("Enter time in seconds how long it took the runner to run a lap of the track"))

if time < 50.5:
    print("Your time of", time, "is faster than average")
if time > 50.5:
    print("Your time of", time, "is slower than average")
if time == 50.5:
    print("Your time of", time, "is average")
# Out:
# Your time of 12.0  is faster than average

# %%
def coconut(string):
    if "coconut" in string:
        return "True"
    else:
        return "False"

list1 = ["apple", "banana", "coconut"]
print(coconut(list1))

list2 = ["apple", "banana", "mango"]
print(coconut(list2))
# Out:
# True
# False

# %%
strings = []

while True:
    string = input("Enter a string:")
    if string  == "":
        break

print(strings)
# Out:
# []
